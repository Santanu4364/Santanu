# %% [markdown]
# # Regular and Raw String

# %%
Regular_string = "name-santanu mandal \n roll-1254 \t"
print(Regular_string)
# Out:
# name-santanu mandal
#  roll-1254

# %%
Raw_String=r"santanu mandal :\n roll-1234 \t"
print(Raw_String)
# Out:
# santanu mandal :\n roll-1234 \t

# %% [markdown]
# # Allignment in format printing
# #### < for left alignment
# #### > for right alignment
# #### ^ for center alignemnt

# %%
print('{:^10}'.format("*"))
print('{:<10}'.format("*"))
print('{:>10}'.format("*"))
# Out:
#     *
# *
#          *
