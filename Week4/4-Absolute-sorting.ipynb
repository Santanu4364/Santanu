# %%
import random
l=[]
x=[]
for i in range (10):
    l.append(random.randint(20,40))
print(l)
while(len(l)>0):
    min=l[0]
    for i in range (len(l)):
        if l[i]<min:
            min=l[i]
    x.append(min)
    l.remove(min)
print(x)
# Out:
# [26, 24, 34, 33, 25, 21, 20, 28, 32, 37]
# [20, 21, 24, 25, 26, 28, 32, 33, 34, 37]

# %% [markdown]
# if i have to print l at last then

# %%
import random
l=[]
for i in range(10):
    l.append(random.randint(20,40))
x=[]
temp=l.copy()
while(len(temp)>0):
    min=temp[0]
    for i in range (len(temp)):
        if temp[i]<min:
            min=temp[i]
    x.append(min)
    temp.remove(min)
print(l)
print(x)
# Out:
# [27, 28, 32, 36, 29, 35, 20, 33, 27, 28]
# [20, 27, 27, 28, 28, 29, 32, 33, 35, 36]
