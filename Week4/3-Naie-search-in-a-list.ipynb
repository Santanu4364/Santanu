# %%
import random
l=[]

for i in range (30):
    l.append(random.randint(1,100))
print(l)
a= int(input("Enter a number: "))

flag=0


for i in range(len(l)):
    if (a==l[i]):
        print("match", i)
        flag=1
        break
if flag==0:
    print("not match")
# Out:
# [42, 78, 91, 88, 3, 79, 47, 63, 13, 2, 38, 36, 42, 73, 95, 60, 41, 49, 18, 25, 6, 76, 99, 39, 54, 56, 79, 87, 43, 6]
# match 0

# %%
import random
l=[]
for i in range (100):
    l.append(random.randint(1,1000))

print(l)
n=0
while(n>-1):
    n=int(input())


    flag = 0
    

    for i in range(len(l)):
        if l[i]==n:
            print("element is found at index",i)
            flag=1
            break
    if flag == 0:
        print("element is not found")
# Out:
# [887, 668, 375, 197, 425, 765, 519, 705, 279, 428, 539, 394, 638, 634, 34, 66, 925, 800, 315, 745, 473, 372, 12, 448, 121, 692, 315, 179, 531, 237, 560, 345, 757, 758, 765, 854, 133, 56, 255, 950, 856, 607, 441, 912, 980, 557, 661, 261, 574, 86, 331, 790, 132, 849, 801, 233, 470, 425, 715, 785, 774, 653, 564, 764, 876, 192, 142, 359, 552, 829, 803, 721, 435, 177, 31, 877, 64, 204, 824, 791, 218, 355, 546, 163, 112, 546, 868, 49, 822, 609, 223, 139, 305, 103, 672, 881, 772, 127, 192, 308]
# element is not found
# element is not found
# element is not found
# element is not found
# element is not found
