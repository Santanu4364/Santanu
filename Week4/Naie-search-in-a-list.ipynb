# %%
import random
l=[]

for i in range (30):
    l.append(random.randint(1,100))
print(l)
a= int(input("Enter a number: "))

flag=0


for i in range(len(l)):
    if (a==l[i]):
        print("match", i)
        flag=1
        break
if flag==0:
    print("not match")
# Out:
# [42, 78, 91, 88, 3, 79, 47, 63, 13, 2, 38, 36, 42, 73, 95, 60, 41, 49, 18, 25, 6, 76, 99, 39, 54, 56, 79, 87, 43, 6]
# match 0
